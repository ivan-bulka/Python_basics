# %% [markdown]
# # Работа с git

# %%
>> git config --global user.name "Your Name"
>> git config --global user.email "your_email@whatever.com"
>> git init
>> git status
>> git add '*.py'
>> git commit -m "add seminar 2 tasks"
>> git remote add origin https://github.com/Yorko/mccme_python_tasks.git
>> git push -u origin master
>> git log
>> git checkout seminar3/3P_3551_sum_factorials.py "возвращаемся к последней версии файла"
>> git checkout -b develop "добавляем ветку"
>> git checkout master "переключаем ветку"
>> git merge develop "мердж ветки develop в мастер"

# %% [markdown]
# # Работа со строками, цыклы for, while

# %%
# Работа со строками
    " " - пробел (очевидно)
    "\t" - табуляция
    "\n" - перенос строки
# Избавление от пробелов или других символов по краям
    name = ' eric '
    print(name.lstrip())
    print(name.rstrip(","))
    print(name.strip("."))
# Поиск подстроки
    "we bought a new house and we are happy".find("we") "возвращает номер первого вхождения"
    "we bought a new house and we are happy".rfind("we") "возвращает номер последнего вхождения"
# Замена по шаблону
    "we bought a new house".replace("house", "building")
# Разбиение строки по разделителю
    "hello#$great#$to#$see#$you".split("#$")
# Сборка строки по разделителю. Применяется к разделителю
    ",".join(["Ann", "Leo", "Tiffany"])
# Форматирование строки
    # key-value pairs: client_id, (name, age, occupation)
        personal_data = {1: ("Ann", 29, "Artist"), 
                       2: ("Leo", 54, "Programmer"), 
                       3: ("Tiffany", 43, "Shop Assistant")}
        for (name, age, occupation) in personal_data.values():
            print("{0} (age {1}) is a {2}".format(name, age, occupation)) 
    # Результат: 
        Ann (age 29) is a Artist
        Leo (age 54) is a Programmer
        Tiffany (age 43) is a Shop Assistant
# if - else:
    # Общая форма
        a = int(input("Insert a number: "))
        if a % 7 == 0:
            print(a)
            print("YES")
        else:
            print("NO")
     # Общая форма. Более сложный пример:        
        x = int(input("Введите x: "))
        y = int(input("Введите y: "))
        if x > 0:
            if y > 0:               # x>0, y>0
                print("Первая четверть")
            else:                   # x>0, y<0
                print("Четвертая четверть")
        else:
            if y > 0:               # x<0, y>0
                print("Вторая четверть")
            else:                   # x<0, y<0
                print("Третья четверть")
    # Сокращенная форма
        has_debts = True
        comission = 0.07 if has_debts else 0.05
        print(comission)
# if-elif-else (каскадная конструкция)
    x = input("Введите x: ")
    y = input("Введите y: ")
    if x > 0 and y > 0:
        print("Первая четверть")
    elif x > 0 and y < 0:
        print("Четвертая четверть")
    elif y > 0:
        print("Вторая четверть")
    else:
        print("Третья четверть")
# While
    # Пример 1
        # Создадим список
        names = []
        # Определим переменную new_name отличную от 'quit'.
        new_name = ''

        # Начнем цикл, который будет выполняться до тех пор, пока не набрано 'quit'.
        while new_name != 'quit':
            # Попросим пользователя ввести имя
            new_name = input("Please tell me someone I should know or enter 'quit': ")

            # Добавим это имя в список который был создан ранее
            names.append(new_name)

        # Покажем что все, что было набрано - добавлено в наш список.
        print(names) 
        
    # Пример 2
        # Установим силы игрока - 5.
        power = 5

        # Играть можно пока сил не станет - 0.
        while power > 0:
            print("You are still playing because your power is %d." % power)
            # игра начинается тут: 
            #   возможная потеря сил
            # Допустим, с каждым разом сила у Люка уменьшается на 1
            power = power - 1
        else:    
            print("\nOh no, your power dropped to 0! Game Over.")
            
break - Производит переход за пределы цикла
continue - Производит переход в начало цикла
pass - Ничего не делает, используется как заполнитель
Блок else - выполняется, если цикл завершился необычным образом (break не в счет)

# for 
    for x in ['spam', 'eggs', 'ham']:
    print(type(x))

# %% [markdown]
# # Списки

# %%
# Инициализация списка
    dogs = ['border collie', 'australian cattle dog', 'labrador retriever']
# Пример
    students = ['bernice', 'aaron', 'cody']
    for student in students:
        print("Hello, " + student.title() + "!")
# Обращение к элементу по индексу
    dog = dogs[0]
    print(dog.title())
# Обращение к последнему элементу
    dog = dogs[-1]
# Обращение ко всем элементам списка
    dogs = ['border collie', 'australian cattle dog', 'labrador retriever']
    for dog in dogs:
        print(dog)
# Метод enumerate для перечисления элементов списка вместе с их индексами
    dogs = ['border collie', 'australian cattle dog', 'labrador retriever']
    print("Results for the dog show are as follows:\n")
    for index, dog in enumerate(dogs):
        place = str(index)
        print("Place: " + place + " Dog: " + dog.title())
# Изменение элемента
    dogs[0] = 'australian shepherd'
# Поиск элемента в списке
    dogs = ['border collie', 'australian cattle dog', 'labrador retriever']
    print(dogs.index('australian cattle dog'))
# Добавления элемента в список (append)
    dogs = ['border collie', 'australian cattle dog', 'labrador retriever']
    dogs.append('poodle')
# Добавления элемента в список (insert)
    dogs = ['border collie', 'australian cattle dog', 'labrador retriever']
    dogs.insert(1, 'poodle')
    print(dogs)
    ['border collie', 'poodle', 'australian cattle dog', 'labrador retriever']
# Создание пустого списка
    usernames = []
# Сортировка списка
    students = ['bernice', 'aaron', 'cody']
    # Put students in alphabetical order.
    students.sort() "меняет расположение элементом в списке"
    #Put students in reverse alphabetical order.
    students.sort(reverse=True)
    # Display students in alphabetical order, but keep the original order. 
    print("Here is the list in alphabetical order:")
    for student in sorted(students): "не меняет расположение элементов в списке"
    print(student.title())
# Изменения порядка 
    students = ['bernice', 'aaron', 'cody']
    students.reverse()
# Длинна списка 
    user_count = len(usernames) 
# Удаление элементов 
    del dogs[0] "по индексу"
    dogs.remove('australian cattle dog') "по значению"
    letters.remove('a') "удаляет первый элемент с заданным значением"
# Извлечение и удаление элемента списка 
    last_dog = dogs.pop() "последний элемент"
    first_dog = dogs.pop(0) "элемент по id"
# Срез списка 
    first_batch = usernames[1:4]
    first_batch = usernames[:3]
    end_batch = usernames[2:]
# Копирование списка 
    copied_usernames = usernames[:]
# Метод range для числовых списков
    for number in range(1,21,2): "2 - шаг"
        print(number)
# Методы min(), max() и sum()
    youngest = min(ages)
    oldest = max(ages)
    total_years = sum(ages)
# Синтаксис сокращенной нотации
    squares = [number**2 for number in range(1,11)]
# Строки как списки 
    message = "Hello!" "Каждый новый элемент в отдельной строке"
    for letter in message:
        print(letter)
    
    message = "Hello world!" "Список"
    message_list = list(message)
        print(message_list)
    ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!']
# Срез стороки
    first_three = message[:3]
    last_three = message[-3:]
# Поиск подстроки
    message = "I like cats and dogs."
    dog_present = 'dog' in message
    print(dog_present)
# Индекс начала нужной подстроки
    message = "I like cats and dogs."
    dog_index = message.find('dog')
    print(dog_index)
# Метод rfind() для поиска индекса последнего вхождения
    message = "I like cats and dogs, but I'd much rather own a dog."
    last_dog_index = message.rfind('dog')
    print(last_dog_index)
# Замена подстроки - метод replace()
    message = "I like cats and dogs, but I'd much rather own a dog."
    message = message.replace('dog', 'snake')
    print(message)
# Подсчет числа подстрок - метод count()
    message = "I like cats and dogs, but I'd much rather own a dog."
    number_dogs = message.count('dog')
    print(number_dogs)
# Разбиение строки - метод split()
    message = "I like cats and dogs, but I'd much rather own a dog."
    words = message.split(' ')
    print(words)

# %% [markdown]
# # Кортежы - это неизменяемый список

# %%
# Определяется круглыми скобками
    colors = ('red', 'green', 'blue')
    print("The first color is: " + colors[0])
# Форматирование строк с помощью кортежей
    animal = 'dog'
    print("I have a %s." % animal)
    
    animals = ['dog', 'cat', 'bear']
    for animal in animals:
        print("I have a %s." % animal)
    
    animals = ('dog', 'cat', 'bear')
    print("I have a %s, a %s, and a %s." % (animals[0], animals[1], animals[2]))
    
    animals = ('dog', 'cat', 'bear')
    print("I have a {0}, a {1}, and a {2}."
      .format(animals[0], animals[1], animals[2]))

# %% [markdown]
# # Словари

# %%
# Словарь - это способ хранения информации, которая каким-то образом связана. 
# Словари хранят информацию в виде пары ключ - значение, то есть, каждая часть информации соединена 
# как минимум с одним значением.
# Общий синтаксис
    dictionary_name = {key_1: value_1, key_2: value_2, key_3: value_3}
# Обращение к элементам словаря 
   python_words = {'list': 'A collection of values that are not connected, but have an order.',
                'dictionary': 'A collection of key-value pairs.',
                'function': 'A named set of instructions that defines a set of actions in Python.',
                }
    print("\nWord: %s" % 'list')
    print("Meaning: %s" % python_words['list']) 
# Более краткая форма обращения к элментам словаря 
    for word, meaning in python_words.items():
        print("\nWord: %s" % word)
        print("Meaning: %s" % meaning)
        
    for meaning in python_words.values(): "Обращение ко второму столбцу"
        print("\nMeaning: %s" % meaning)
# Преобразование в строку 
    python_words.items()
# Добавление новой пары
    python_words = {}
    python_words['function'] = 'A named set of instructions that defines a set of actions in Python.'
# Изменение значения 
    python_words['function'] = 'BlaBlaBla'
# Удаления значения
    del python_words['list']
# Изменение ключа
    python_words['list'] = python_words['lisst']
    del python_words['lisst']
# Сортирование ключей 
    sorted(python_words.keys())
# Nestling позвоняет завернуть один словарь внутрь другого
    favorite_numbers = {'eric': [3, 11, 19, 23, 42],
                    'ever': [2, 4, 5],
                    'willie': [5, 35, 120],
                    }
    # Display each person's favorite numbers.
    for name in favorite_numbers:
        print("\n%s's favorite numbers are:" % name.title())
        print(favorite_numbers[name])   
    
    # This program stores people's favorite numbers, and displays them.
    favorite_numbers = {'eric': [3, 11, 19, 23, 42],
                    'ever': [2, 4, 5],
                    'willie': [5, 35, 120],
                   }
    # Результат
        Willie's favorite numbers are:
        [5, 35, 120]
        Eric's favorite numbers are:
        [3, 11, 19, 23, 42]
        Ever's favorite numbers are:
        [2, 4, 5]
    
    # Display each person's favorite numbers.
    for name in favorite_numbers:
        print("\n%s's favorite numbers are:" % name.title())

        # Each value is itself a list, so let's put that list in a variable.
        current_favorite_numbers = favorite_numbers[name]
        for favorite_number in current_favorite_numbers:
            print(favorite_number) 
    # Результат
        Willie's favorite numbers are:
        5
        35
        120

        Eric's favorite numbers are:
        3
        11
        19
        23
        42

        Ever's favorite numbers are:
        2
        4
        5
# Словарь в словаре 
        pets = {'willie': {'kind': 'dog', 'owner': 'eric', 'vaccinated': True},
                'walter': {'kind': 'cockroach', 'owner': 'eric', 'vaccinated': False},
                'peso': {'kind': 'dog', 'owner': 'chloe', 'vaccinated': True},
                }

        # Let's show all the information for each pet.
        for pet_name, pet_information in pets.items():
            print("\nHere is what I know about %s:" % pet_name.title())
            # Each animal's dictionary is in 'information'
            for key in pet_information:
                print(key + ": " + str(pet_information[key]))
        # Результат: 
        Here is what I know about Walter:
        owner: eric
        kind: cockroach
        vaccinated: False

        Here is what I know about Willie:
        owner: eric
        kind: dog
        vaccinated: True

        Here is what I know about Peso:
        owner: chloe
        kind: dog
        vaccinated: True

# %% [markdown]
# # Чтение данных из файла в словарь

# %%
credit_history_file = open('../data/credit_sample.txt', 'r')
print(credit_history_file.readline()) "Выводим первую строку"
for line in credit_history_file:
    line = line.strip().split(",")
    print(line)
    
credit_history_file = open('../data/credit_sample.txt', 'r')
# let's for now just skip the heading
first_line = credit_history_file.readline()
print(first_line)
credit_history_dict = {}
for line in credit_history_file:
    lastname, age, debt, occupation = line.strip().split(",")
    credit_history_dict[lastname] = (int(age), 
                                     int(debt), 
                                     occupation) 
print(credit_history_dict)   
credit_history_file.close()

"Запись данных в файл"
output_file = "C:/Users/ivan1/Desktop/new_file.txt"
myfile2 = open(output_file, mode='w', encoding='utf-8')
for line in myfile:
    if "Max" in line:
        print("Max exist in the list")
        myfile2.write("Found password" + "Max\n" )

# %% [markdown]
# # Множества. Содержит элементы в лучайном порядке, которые не могут повторяться

# %%
a = set([1, 2, 3])
b = {4, 5, 6} # {} - dict, not set
print(a)
print(b)
# Результат 
    {1, 2, 3}
    {4, 5, 6}
a = {i ** 2 for i in range(10)}
print(a)
# Результат
    {0, 1, 64, 4, 36, 9, 16, 49, 81, 25}
# Число элементов в множестве
    len({3, 5, 7, 8})
# set.issubset(other) (или set <= other) - является ли множество подмножеством другого (other)
    print({2, 5, 6}.issubset({2, 4, 8, 3, 5, 6}))
    print({2, 5, 6} <= {2, 4, 8, 3, 5, 6})
# Объединение множеств
    {2, 5, 7}.union({2, 8, 3, 5, 6})
# Пересечение множеств
    {2, 5, 7, 4, 3, 5}.intersection({2, 4, 7}, {2, 7})
# set.difference(other, ...) (или set - other) - множество из всех элементов set, не принадлежащие ни одному из other.
    {2, 5, 7, 4, 3, 5} - {2, 4, 7}
# set.symmetric_difference(other) (или set ^ other) - множество из элементов, встречающихся в одном множестве, 
# но не встречающиеся в обоих.
    {1, 2, 3, 4, 5}.symmetric_difference({3, 4, 5, 6, 7})
set.add(elem) - добавляет элемент в множество.
set.remove(elem) - удаляет элемент из множества. KeyError, если такого элемента не существует.
set.discard(elem) - удаляет элемент, если он находится в множестве.
set.pop() - удаляет первый элемент из множества. Так как множества не упорядочены, нельзя точно сказать, какой элемент будет первым.
set.clear() - очистка множества.

# %% [markdown]
# # Frozenset - то же множество, только неизменяемое

# %%
detroit_fans = frozenset(["Harry", "Nick"])
